# %% [markdown]
# # Author: Soora Sampath
# # The Sparks Foundation
# # Task 6: Prediction using Decision Tree Algorithm
# # Data Science and Business Analytics

# %% [markdown]
# # Task is to create a decision tree classifier and visualize it

# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import tree

# %% [markdown]
# # Loading raw data

# %%
rawData = datasets.load_iris()
x=pd.DataFrame(rawData.data, columns=rawData.feature_names)

# %% [markdown]
# # Studying the raw data

# %%
x.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
x.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %%
y=pd.DataFrame(rawData.target,columns=["Species"])

# %%
y
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (120, 4)

# %%
y_train.shape
# Out:
# (120, 1)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
y_test.shape
# Out:
# (30, 1)

# %% [markdown]
# # Creating decision trees

# %%
dt= DecisionTreeClassifier() # uses gini

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.predict(x_test)
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
y_test
# Out:
#      Species
# 114        2
# 62         1
# 33         0
# 107        2
# 7          0
# 100        2
# 40         0
# 86         1
# 76         1
# 71         1
# 134        2
# 51         1
# 73         1
# 54         1
# 63         1
# 37         0
# 78         1
# 90         1
# 45         0
# 16         0
# 121        2
# 66         1
# 24         0
# 8          0
# 126        2
# 22         0
# 44         0
# 97         1
# 93         1
# 26         0

# %% [markdown]
# # Checking the decision trees

# %%
dt.score(x_test,y_test)
# Out:
# 1.0

# %% [markdown]
# # Score: 1 (with gini)

# %%
dt2= DecisionTreeClassifier(criterion='entropy',max_depth=5) # uses entropy

# %%
dt2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
dt2.score(x_test,y_test)
# Out:
# 1.0

# %% [markdown]
# # Score: 1 (with entropy)

# %% [markdown]
# # Prediction on testing data

# %%
Y_pred=dt.predict(x_test)

# %%
Y_pred
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
y_test
# Out:
#      Species
# 114        2
# 62         1
# 33         0
# 107        2
# 7          0
# 100        2
# 40         0
# 86         1
# 76         1
# 71         1
# 134        2
# 51         1
# 73         1
# 54         1
# 63         1
# 37         0
# 78         1
# 90         1
# 45         0
# 16         0
# 121        2
# 66         1
# 24         0
# 8          0
# 126        2
# 22         0
# 44         0
# 97         1
# 93         1
# 26         0

# %% [markdown]
# # Visualize the trees

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(dt, 
                   feature_names=rawData.feature_names,  
                   class_names=rawData.target_names,
                   filled=True)
